# %% [markdown]
# ####이론

# %% [markdown]
# 0. 자연어 처리 모델에서 사용하는 Transformer를 이미지 분류에 적용시킨 Vision Transformer에 관한 논문입니다.

# %% [markdown]
# 1. 이미지를 patch 단위로 쪼개 '토큰화'시키고,
# 이들을 Linear Projection 과정(벡터화 과정)을 거쳐 Position Embedding시켜 순서를 부여한 뒤 Transformer Encoder의 입력으로 들어가게 됩니다.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Transformer Encoder 내부에서는 먼저 Layer Normalization을 거치고, Multi-Head Attention을 지난 결과를 통과하지 않은 패치와 Skip Connection 시켜줍니다. 그리고 다시 Layer Nomalization, MLP를 거쳐 Skip Connection으로 다시 더해주는 것이 한 번 Transformer Encoder를 통과한 것입니다.
# 이러한 Transformer Encoder를 L번 반복합니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. 만약 이미지가 (C,H,W) 크기
#
#
# ![image.png](data:image/png;base64,...)
# 이며,
#
#
#
# 패치 사이즈가 (P,P)이면
#
# ![image.png](data:image/png;base64,...)
#
#
#
# 총 패치의 개수 N = HW/P^2 이고,
#
# 패치의 차원은
#
# ![image.png](data:image/png;base64,...)
#
# 으로 이미지를 패치화합니다.

# %% [markdown]
# 4. 각각의 n개의 patch를 D차원으로 벡터화하는데,그 결과가 n개의 xpE 입니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. n개의 벡터에 Position Embedding을 시켜줘야 하는데 Epos를 더해 z0를 생성합니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. z0가 Transformer Encoder 내부에서 1번 Encoding되는 과정은 다음과 같습니다.
#
# ![image.png](data:image/png;base64,...)
#
# 이러한 과정을 L번 반복합니다.

# %% [markdown]
# 7. Encoding 과정을 L번 반복하고 그 결과값을 Layer Nomalization을 거치고 MLP head를 거쳐 softmax 결과에 따라 class로 나눠집니다.
#
# ![image.png](data:image/png;base64,...)
#
#
# 이 때, mlp head의 입력은 D차원 벡터이며
#  (Transformer Encoder의 입출력 차원은 D차원이다),

# %% [markdown]
# ####구현
#
# 구현할 모델에서는 Layer의 개수를 12개, D의 크기를 64, MLP의 크기를 1024, Head 개수를 4로 설정하여 진행한다.

# %%
# tensorflow_addons를 사용하기 위해 설치해줘야 한다.
# %pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.22.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)

# %%
import numpy as np
import tensorflow as tf
import keras
from keras import layers          # vision transformer를 구성하는데 사용 (vit함수)
import tensorflow_addons as tfa

# %%
print(tf.__version__)   # tensorflow 2.14.0 버전을 사용한다.
# Out:
# 2.14.0

# %% [markdown]
# 데이터는 cifar100을 사용한다.
# 32 x 32 크기의 60000개의 이미지로 이루어져 있으며, 100개의 클래스로 분류(dolphin, fish ...) 되며 각각의 클래스는 600개의 이미지로 이루어져 있다.
# 또, 500개는 학습 데이터, 100개는 데이터 데이터로 이루어져 있어 총 50000개의 학습 데이터, 10000개의 테스트 데이터로 이루어져있다.

# %%
num_classes = 100         # cifar100 사용하므로 class를 100개로 지정
input_shape = (32,32,3)   # input shape는 32x32의 RGB 채널을 가진 이미지이다.

# 데이터 로드 (train과 test를 나눠서 로드한다)
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape : {x_train.shape}, y_train shape : {y_train.shape}")
print(f"x_test shape : {x_test.shape}, y_test shape : {y_test.shape}")
# Out:
# x_train shape : (50000, 32, 32, 3), y_train shape : (50000, 1)
# x_test shape : (10000, 32, 32, 3), y_test shape : (10000, 1)

# %%
batch_size = 256

image_size = 224    # 16x16 이미지를 업사이징하여 224x224로 만들것이다.
patch_size = 32     # 패치 사이즈는 32x32,
num_patches = (image_size//patch_size)**2     # 패치의 개수는 이미지 크기를 패치사이즈로 나누고 제곱한다.

# D 차원으로 벡터화
projection_dim = 64   # D = 64
num_heads = 4

# mlp에서 사용하는 transformer unit (128, 64)
transformer_units = [
    projection_dim*2,
    projection_dim,
]

transformer_layers = 12         # layer의 개수
mlp_head_units = [2048, 1024]

# %%
# 이미지 업사이징, 전처리
data_augmentation = keras.Sequential(
    [
            layers.Normalization(),                         # Normalize
            layers.Resizing(image_size, image_size),        # 224 x 224
            layers.RandomFlip('horizontal'),
            layers.RandomRotation(factor=0.02),
            layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name = 'data_augmentation',
)

data_augmentation.layers[0].adapt(x_train)

# %%
# mlp 함수
def mlp(x, hidden_units, dropout_rate):
  for units in hidden_units:
      x = layers.Dense(units, activation=tf.nn.gelu)(x)   # 활성화함수로 gelu를 사용
      x = layers.Dropout(dropout_rate)(x)                 # dropout을 사용한다.
  return x

# %%
# 패치화하는 클래스
class Patches(layers.Layer):
  def __init__(self, patch_size):
    super().__init__()
    self.patch_size = patch_size

  def call(self, images):
    batch_size = tf.shape(images)[0]
    patches = tf.image.extract_patches(
        images = images,
        sizes = [1, self.patch_size, self.patch_size, 1],
        strides = [1, self.patch_size, self.patch_size, 1],
        rates = [1,1,1,1],
        padding = "VALID",    # padding 사용 X
    )
    patch_dims = patches.shape[-1]
    patches = tf.reshape(patches, [batch_size, -1, patch_dims])
    return patches

# %%
import matplotlib.pyplot as plt

# 패치화 결과 확인
plt.figure(figsize=(4,4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype('uint8'))
plt.axis('off')

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size = (image_size, image_size)
)

patches = Patches(patch_size)(resized_image)
print(f'Image size: {image_size} X {image_size}')
print(f'Patch size: {patch_size} X {patch_size}')
print(f'Patches per image: {patches.shape[1]}')
print(f'Elements per patch: {patches.shape[-1]}')
print(f'Shape of patch: {patches.shape}')

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize = (4,4))
for i, patch in enumerate(patches[0]):
  ax = plt.subplot(n, n, i+1)
  patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
  plt.imshow(patch_img.numpy().astype('uint8'))
  plt.axis('off')
# Out:
# Image size: 224 X 224
# Patch size: 32 X 32
# Patches per image: 49
# Elements per patch: 3072
# Shape of patch: (1, 49, 3072)

# %%
# PatchEncoder를 class로 정의
# (Linear Projection -> Position Embedding)
class PatchEncoder(layers.Layer):
  def __init__(self, num_patches, projection_dim):
    super().__init__()
    self.num_patches = num_patches

    self.projection = layers.Dense(units=projection_dim)      # D차원으로 Linear Projection
    self.position_embedding = layers.Embedding(               # position embedding
        input_dim = num_patches, output_dim = projection_dim
    )

  def call(self, patch):
    positions = tf.range(start=0, limit=self.num_patches, delta=1)          # 0부터 patch개수만큼 1씩 증가하는 position
    encoded = self.projection(patch) + self.position_embedding(positions)   # position embedding 과정
    return encoded  # z0

# %%
# vision transformer
def vit():

  # 1) Patch화 ->  patch를 Linear Projection -> Position Embedding
  inputs = layers.Input(shape=input_shape)
  augmented = data_augmentation(inputs)     # inputs를 업사이징
  patches = Patches(patch_size)(augmented)  # patch 생성 (patches)
  encoded_patches = PatchEncoder(num_patches, projection_dim)(patches) # patch를 Linear Projection -> Position Embedding


  # 2) Transformer Encoder L번 반복
  for _ in range(transformer_layers):   # L번 반복

    x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)       # 1) Norm

    attention_output = layers.MultiHeadAttention(                       # 2) Multi-Head Attention
        num_heads = num_heads, key_dim = projection_dim, dropout=0.1
    )(x1, x1)

    x2 = layers.Add()([attention_output, encoded_patches])              # 3) Skip Connection

    x3 = layers.LayerNormalization(epsilon=1e-6)(x2)                    # 4) Norm

    x3 = mlp(x3, hidden_units = transformer_units, dropout_rate = 0.1)  # 5) MLP

    encoded_patches = layers.Add()([x3, x2])                            # 6) Skip Connection


  # 3) MLP Head에 들어가기 전 레이어정규화
  representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
  representation = layers.Flatten()(representation)
  representation = layers.Dropout(0.5)(representation)


  # 4) MLP Head
  features = mlp(representation, hidden_units = mlp_head_units, dropout_rate = 0.5)


  # 5) class화
  logits = layers.Dense(num_classes)(features)


  # 6) 모델 생성
  model = keras.Model(inputs=inputs, outputs = logits)

  return model

# %%
model = vit()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 224, 224, 3)          7         ['input_1[0][0]']
#  ial)
#
#  patches_1 (Patches)         (None, None, 3072)           0         ['data_augmentation[0][0]']
#
#  patch_encoder (PatchEncode  (None, 49, 64)               199808    ['patches_1[0][0]']
#  r)
#
#  layer_normalization (Layer  (None, 49, 64)               128       ['patch_encoder[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 49, 64)               66368     ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 49, 64)               0         ['multi_head_attention[0][0]',
#                                                                      'patch_encoder[0][0]']
#
#  layer_normalization_1 (Lay  (None, 49, 64)               128       ['add[0][0]']
#  erNormalization)
#
#  dense_1 (Dense)             (None, 49, 128)              8320      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 49, 128)              0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 49, 64)               8256      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 49, 64)               0         ['dense_2[0][0]']
#
#  add_1 (Add)                 (None, 49, 64)               0         ['dropout_1[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 49, 64)               128       ['add_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 49, 64)               66368     ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 49, 64)               0         ['multi_head_attention_1[0][0]
#                                                                     ',
#                                                                      'add_1[0][0]']
#
#  layer_normalization_3 (Lay  (None, 49, 64)               128       ['add_2[0][0]']
#  erNormalization)
#
#  dense_3 (Dense)             (None, 49, 128)              8320      ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 49, 128)              0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 49, 64)               8256      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 49, 64)               0         ['dense_4[0][0]']
#
#  add_3 (Add)                 (None, 49, 64)               0         ['dropout_3[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_4 (Lay  (None, 49, 64)               128       ['add_3[0][0]']
#  erNormalization)
#
#  multi_head_attention_2 (Mu  (None, 49, 64)               66368     ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 49, 64)               0         ['multi_head_attention_2[0][0]
#                                                                     ',
#                                                                      'add_3[0][0]']
#
#  layer_normalization_5 (Lay  (None, 49, 64)               128       ['add_4[0][0]']
#  erNormalization)
#
#  dense_5 (Dense)             (None, 49, 128)              8320      ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 49, 128)              0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 49, 64)               8256      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 49, 64)               0         ['dense_6[0][0]']
#
#  add_5 (Add)                 (None, 49, 64)               0         ['dropout_5[0][0]',
#                                                                      'add_4[0][0]']
#
#  layer_normalization_6 (Lay  (None, 49, 64)               128       ['add_5[0][0]']
#  erNormalization)
#
#  multi_head_attention_3 (Mu  (None, 49, 64)               66368     ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 49, 64)               0         ['multi_head_attention_3[0][0]
#                                                                     ',
#                                                                      'add_5[0][0]']
#
#  layer_normalization_7 (Lay  (None, 49, 64)               128       ['add_6[0][0]']
#  erNormalization)
#
#  dense_7 (Dense)             (None, 49, 128)              8320      ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 49, 128)              0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 49, 64)               8256      ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 49, 64)               0         ['dense_8[0][0]']
#
#  add_7 (Add)                 (None, 49, 64)               0         ['dropout_7[0][0]',
#                                                                      'add_6[0][0]']
#
#  layer_normalization_8 (Lay  (None, 49, 64)               128       ['add_7[0][0]']
#  erNormalization)
#
#  multi_head_attention_4 (Mu  (None, 49, 64)               66368     ['layer_normalization_8[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_8[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 49, 64)               0         ['multi_head_attention_4[0][0]
#                                                                     ',
#                                                                      'add_7[0][0]']
#
#  layer_normalization_9 (Lay  (None, 49, 64)               128       ['add_8[0][0]']
#  erNormalization)
#
#  dense_9 (Dense)             (None, 49, 128)              8320      ['layer_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_8 (Dropout)         (None, 49, 128)              0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 49, 64)               8256      ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 49, 64)               0         ['dense_10[0][0]']
#
#  add_9 (Add)                 (None, 49, 64)               0         ['dropout_9[0][0]',
#                                                                      'add_8[0][0]']
#
#  layer_normalization_10 (La  (None, 49, 64)               128       ['add_9[0][0]']
#  yerNormalization)
#
#  multi_head_attention_5 (Mu  (None, 49, 64)               66368     ['layer_normalization_10[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_10[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 49, 64)               0         ['multi_head_attention_5[0][0]
#                                                                     ',
#                                                                      'add_9[0][0]']
#
#  layer_normalization_11 (La  (None, 49, 64)               128       ['add_10[0][0]']
#  yerNormalization)
#
#  dense_11 (Dense)            (None, 49, 128)              8320      ['layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 49, 128)              0         ['dense_11[0][0]']
#
#  dense_12 (Dense)            (None, 49, 64)               8256      ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 49, 64)               0         ['dense_12[0][0]']
#
#  add_11 (Add)                (None, 49, 64)               0         ['dropout_11[0][0]',
#                                                                      'add_10[0][0]']
#
#  layer_normalization_12 (La  (None, 49, 64)               128       ['add_11[0][0]']
#  yerNormalization)
#
#  multi_head_attention_6 (Mu  (None, 49, 64)               66368     ['layer_normalization_12[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_12[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 49, 64)               0         ['multi_head_attention_6[0][0]
#                                                                     ',
#                                                                      'add_11[0][0]']
#
#  layer_normalization_13 (La  (None, 49, 64)               128       ['add_12[0][0]']
#  yerNormalization)
#
#  dense_13 (Dense)            (None, 49, 128)              8320      ['layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 49, 128)              0         ['dense_13[0][0]']
#
#  dense_14 (Dense)            (None, 49, 64)               8256      ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)        (None, 49, 64)               0         ['dense_14[0][0]']
#
#  add_13 (Add)                (None, 49, 64)               0         ['dropout_13[0][0]',
#                                                                      'add_12[0][0]']
#
#  layer_normalization_14 (La  (None, 49, 64)               128       ['add_13[0][0]']
#  yerNormalization)
#
#  multi_head_attention_7 (Mu  (None, 49, 64)               66368     ['layer_normalization_14[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_14[0][0]
#                                                                     ']
#
#  add_14 (Add)                (None, 49, 64)               0         ['multi_head_attention_7[0][0]
#                                                                     ',
#                                                                      'add_13[0][0]']
#
#  layer_normalization_15 (La  (None, 49, 64)               128       ['add_14[0][0]']
#  yerNormalization)
#
#  dense_15 (Dense)            (None, 49, 128)              8320      ['layer_normalization_15[0][0]
#                                                                     ']
#
#  dropout_14 (Dropout)        (None, 49, 128)              0         ['dense_15[0][0]']
#
#  dense_16 (Dense)            (None, 49, 64)               8256      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 49, 64)               0         ['dense_16[0][0]']
#
#  add_15 (Add)                (None, 49, 64)               0         ['dropout_15[0][0]',
#                                                                      'add_14[0][0]']
#
#  layer_normalization_16 (La  (None, 49, 64)               128       ['add_15[0][0]']
#  yerNormalization)
#
#  multi_head_attention_8 (Mu  (None, 49, 64)               66368     ['layer_normalization_16[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_16[0][0]
#                                                                     ']
#
#  add_16 (Add)                (None, 49, 64)               0         ['multi_head_attention_8[0][0]
#                                                                     ',
#                                                                      'add_15[0][0]']
#
#  layer_normalization_17 (La  (None, 49, 64)               128       ['add_16[0][0]']
#  yerNormalization)
#
#  dense_17 (Dense)            (None, 49, 128)              8320      ['layer_normalization_17[0][0]
#                                                                     ']
#
#  dropout_16 (Dropout)        (None, 49, 128)              0         ['dense_17[0][0]']
#
#  dense_18 (Dense)            (None, 49, 64)               8256      ['dropout_16[0][0]']
#
#  dropout_17 (Dropout)        (None, 49, 64)               0         ['dense_18[0][0]']
#
#  add_17 (Add)                (None, 49, 64)               0         ['dropout_17[0][0]',
#                                                                      'add_16[0][0]']
#
#  layer_normalization_18 (La  (None, 49, 64)               128       ['add_17[0][0]']
#  yerNormalization)
#
#  multi_head_attention_9 (Mu  (None, 49, 64)               66368     ['layer_normalization_18[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_18[0][0]
#                                                                     ']
#
#  add_18 (Add)                (None, 49, 64)               0         ['multi_head_attention_9[0][0]
#                                                                     ',
#                                                                      'add_17[0][0]']
#
#  layer_normalization_19 (La  (None, 49, 64)               128       ['add_18[0][0]']
#  yerNormalization)
#
#  dense_19 (Dense)            (None, 49, 128)              8320      ['layer_normalization_19[0][0]
#                                                                     ']
#
#  dropout_18 (Dropout)        (None, 49, 128)              0         ['dense_19[0][0]']
#
#  dense_20 (Dense)            (None, 49, 64)               8256      ['dropout_18[0][0]']
#
#  dropout_19 (Dropout)        (None, 49, 64)               0         ['dense_20[0][0]']
#
#  add_19 (Add)                (None, 49, 64)               0         ['dropout_19[0][0]',
#                                                                      'add_18[0][0]']
#
#  layer_normalization_20 (La  (None, 49, 64)               128       ['add_19[0][0]']
#  yerNormalization)
#
#  multi_head_attention_10 (M  (None, 49, 64)               66368     ['layer_normalization_20[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_20[0][0]
#                                                                     ']
#
#  add_20 (Add)                (None, 49, 64)               0         ['multi_head_attention_10[0][0
#                                                                     ]',
#                                                                      'add_19[0][0]']
#
#  layer_normalization_21 (La  (None, 49, 64)               128       ['add_20[0][0]']
#  yerNormalization)
#
#  dense_21 (Dense)            (None, 49, 128)              8320      ['layer_normalization_21[0][0]
#                                                                     ']
#
#  dropout_20 (Dropout)        (None, 49, 128)              0         ['dense_21[0][0]']
#
#  dense_22 (Dense)            (None, 49, 64)               8256      ['dropout_20[0][0]']
#
#  dropout_21 (Dropout)        (None, 49, 64)               0         ['dense_22[0][0]']
#
#  add_21 (Add)                (None, 49, 64)               0         ['dropout_21[0][0]',
#                                                                      'add_20[0][0]']
#
#  layer_normalization_22 (La  (None, 49, 64)               128       ['add_21[0][0]']
#  yerNormalization)
#
#  multi_head_attention_11 (M  (None, 49, 64)               66368     ['layer_normalization_22[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_22[0][0]
#                                                                     ']
#
#  add_22 (Add)                (None, 49, 64)               0         ['multi_head_attention_11[0][0
#                                                                     ]',
#                                                                      'add_21[0][0]']
#
#  layer_normalization_23 (La  (None, 49, 64)               128       ['add_22[0][0]']
#  yerNormalization)
#
#  dense_23 (Dense)            (None, 49, 128)              8320      ['layer_normalization_23[0][0]
#                                                                     ']
#
#  dropout_22 (Dropout)        (None, 49, 128)              0         ['dense_23[0][0]']
#
#  dense_24 (Dense)            (None, 49, 64)               8256      ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)        (None, 49, 64)               0         ['dense_24[0][0]']
#
#  add_23 (Add)                (None, 49, 64)               0         ['dropout_23[0][0]',
#                                                                      'add_22[0][0]']
#
#  layer_normalization_24 (La  (None, 49, 64)               128       ['add_23[0][0]']
#  yerNormalization)
#
#  flatten (Flatten)           (None, 3136)                 0         ['layer_normalization_24[0][0]
#                                                                     ']
#
#  dropout_24 (Dropout)        (None, 3136)                 0         ['flatten[0][0]']
#
#  dense_25 (Dense)            (None, 2048)                 6424576   ['dropout_24[0][0]']
#
#  dropout_25 (Dropout)        (None, 2048)                 0         ['dense_25[0][0]']
#
#  dense_26 (Dense)            (None, 1024)                 2098176   ['dropout_25[0][0]']
#
#  dropout_26 (Dropout)        (None, 1024)                 0         ['dense_26[0][0]']
#
#  dense_27 (Dense)            (None, 100)                  102500    ['dropout_26[0][0]']
#
# ==================================================================================================
# Total params: 9823595 (37.47 MB)
# Trainable params: 9823588 (37.47 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________

# %%
# 학습 / 테스트
num_epochs = 20
weight_decay = 0.001
learning_rate = 0.001

optimizer = tfa.optimizers.AdamW(
    learning_rate = learning_rate, weight_decay = weight_decay
)

model.compile(
    optimizer = optimizer,
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name='accuracy'),
        keras.metrics.SparseTopKCategoricalAccuracy(5, name='top-5-accuracy'),
    ],
)

history = model.fit(
    x=x_train,
    y=y_train,
    batch_size = batch_size,
    epochs = num_epochs,
    validation_split = 0.1,
)
# Out:
# Epoch 1/20
# 176/176 [==============================] - 63s 208ms/step - loss: 4.3036 - accuracy: 0.0622 - top-5-accuracy: 0.2076 - val_loss: 3.7282 - val_accuracy: 0.1390 - val_top-5-accuracy: 0.3734
# Epoch 2/20
# 176/176 [==============================] - 32s 181ms/step - loss: 3.7325 - accuracy: 0.1256 - top-5-accuracy: 0.3562 - val_loss: 3.4009 - val_accuracy: 0.1872 - val_top-5-accuracy: 0.4542
# Epoch 3/20
# 176/176 [==============================] - 35s 199ms/step - loss: 3.4587 - accuracy: 0.1715 - top-5-accuracy: 0.4347 - val_loss: 3.2010 - val_accuracy: 0.2206 - val_top-5-accuracy: 0.5046
# Epoch 4/20
# 176/176 [==============================] - 32s 183ms/step - loss: 3.2947 - accuracy: 0.2016 - top-5-accuracy: 0.4788 - val_loss: 3.0717 - val_accuracy: 0.2464 - val_top-5-accuracy: 0.5332
# Epoch 5/20
# 176/176 [==============================] - 33s 188ms/step - loss: 3.1823 - accuracy: 0.2217 - top-5-accuracy: 0.5119 - val_loss: 3.0028 - val_accuracy: 0.2538 - val_top-5-accuracy: 0.5552
# Epoch 6/20
# 176/176 [==============================] - 32s 184ms/step - loss: 3.0926 - accuracy: 0.2373 - top-5-accuracy: 0.5323 - val_loss: 2.9495 - val_accuracy: 0.2672 - val_top-5-accuracy: 0.5710
# Epoch 7/20
# 176/176 [==============================] - 36s 202ms/step - loss: 3.0289 - accuracy: 0.2486 - top-5-accuracy: 0.5468 - val_loss: 2.9005 - val_accuracy: 0.2774 - val_top-5-accuracy: 0.5794
# Epoch 8/20
# 176/176 [==============================] - 32s 183ms/step - loss: 2.9747 - accuracy: 0.2588 - top-5-accuracy: 0.5636 - val_loss: 2.8617 - val_accuracy: 0.2872 - val_top-5-accuracy: 0.5866
# Epoch 9/20
# 176/176 [==============================] - 35s 202ms/step - loss: 2.9307 - accuracy: 0.2658 - top-5-accuracy: 0.5756 - val_loss: 2.8161 - val_accuracy: 0.2970 - val_top-5-accuracy: 0.5986
# Epoch 10/20
# 176/176 [==============================] - 34s 193ms/step - loss: 2.8946 - accuracy: 0.2769 - top-5-accuracy: 0.5818 - val_loss: 2.8060 - val_accuracy: 0.2966 - val_top-5-accuracy: 0.5964
# Epoch 11/20
# 176/176 [==============================] - 33s 187ms/step - loss: 2.8620 - accuracy: 0.2817 - top-5-accuracy: 0.5881 - val_loss: 2.7517 - val_accuracy: 0.3098 - val_top-5-accuracy: 0.6134
# Epoch 12/20
# 176/176 [==============================] - 35s 197ms/step - loss: 2.8278 - accuracy: 0.2876 - top-5-accuracy: 0.5987 - val_loss: 2.7661 - val_accuracy: 0.3112 - val_top-5-accuracy: 0.6152
# Epoch 13/20
# 176/176 [==============================] - 32s 183ms/step - loss: 2.8052 - accuracy: 0.2933 - top-5-accuracy: 0.6036 - val_loss: 2.7289 - val_accuracy: 0.3162 - val_top-5-accuracy: 0.6150
# Epoch 14/20
# 176/176 [==============================] - 32s 183ms/step - loss: 2.7912 - accuracy: 0.2938 - top-5-accuracy: 0.6058 - val_loss: 2.7595 - val_accuracy: 0.3098 - val_top-5-accuracy: 0.6080
# Epoch 15/20
# 176/176 [==============================] - 33s 187ms/step - loss: 2.7669 - accuracy: 0.3006 - top-5-accuracy: 0.6109 - val_loss: 2.7068 - val_accuracy: 0.3202 - val_top-5-accuracy: 0.6204
# Epoch 16/20
# 176/176 [==============================] - 32s 185ms/step - loss: 2.7516 - accuracy: 0.3034 - top-5-accuracy: 0.6120 - val_loss: 2.7374 - val_accuracy: 0.3118 - val_top-5-accuracy: 0.6218
# Epoch 17/20
# 176/176 [==============================] - 32s 184ms/step - loss: 2.7240 - accuracy: 0.3056 - top-5-accuracy: 0.6231 - val_loss: 2.6541 - val_accuracy: 0.3358 - val_top-5-accuracy: 0.6284
# Epoch 18/20
# 176/176 [==============================] - 33s 185ms/step - loss: 2.7131 - accuracy: 0.3090 - top-5-accuracy: 0.6276 - val_loss: 2.6872 - val_accuracy: 0.3210 - val_top-5-accuracy: 0.6292
# Epoch 19/20
# 176/176 [==============================] - 32s 184ms/step - loss: 2.7006 - accuracy: 0.3120 - top-5-accuracy: 0.6278 - val_loss: 2.6719 - val_accuracy: 0.3246 - val_top-5-accuracy: 0.6344
# Epoch 20/20
# 176/176 [==============================] - 32s 184ms/step - loss: 2.6898 - accuracy: 0.3162 - top-5-accuracy: 0.6279 - val_loss: 2.6521 - val_accuracy: 0.3298 - val_top-5-accuracy: 0.6384

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['val_loss'], 'r-', label='val_loss')
plt.xlabel('Epochs')
plt.grid()
plt.legend()


plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], 'b--', label='accuracy')
plt.plot(history.history['val_accuracy'], 'r-', label='val_accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend()
